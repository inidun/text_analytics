# %%
import os
import sys

root_folder = os.path.join(os.getcwd().split('text_analytics')[0], 'text_analytics')

sys.path = list(set(sys.path + [ root_folder ]))

from text_analytic_tools.corpus import vectorized_corpus
sys.version
# Out:
# '3.8.2 (default, Jul 16 2020, 14:00:26) \n[GCC 9.3.0]'

# %%
corpus_tag = 'legal_instrument_corpus_L2_+N_+S'
corpus_folder = os.path.join(root_folder, 'data')

x_corpus = vectorized_corpus.VectorizedCorpus\
    .load(corpus_tag, folder=corpus_folder)\
    .stats()
    
    #.slice_by_n_count(n_count)\
    #.slice_by_n_top(n_top)
    #.filter(year_filter)\
# Out:
# INFO:text_analytic_tools:#bags: 82, #vocab: 8144, #tokens: 255054
# INFO:text_analytic_tools:   bags: 82
# INFO:text_analytic_tools:   vocabulay_size: 8144
# INFO:text_analytic_tools:   sum_over_bags: 255054
# INFO:text_analytic_tools:   10_top_tokens: the of and to in or for be by as

# %%
x_corpus.n_top_tokens(500)
# Out:
# {'the': 20530,
#  'of': 15731,
#  'and': 11938,
#  'to': 8534,
#  'in': 6349,
#  'or': 3519,
#  'for': 3171,
#  'be': 2907,
#  'by': 2448,
#  'as': 2175,
#  'shall': 2114,
#  'that': 2023,
#  'should': 1991,
#  'this': 1859,
#  'cultural': 1828,
#  'with': 1793,
#  'article': 1698,
#  'on': 1612,
#  'convention': 1556,
#  'states': 1555,
#  'which': 1525,
#  'their': 1435,
#  'education': 1383,
#  'is': 1347,
#  'international': 1117,
#  'state': 1111,
#  'all': 1070,
#  'other': 1065,
#  'any': 1025,
#  'its': 1009,
#  'such': 973,
#  'are': 962,
#  'at': 934,
#  'it': 920,
#  'not': 796,
#  'contracting': 789,
#  'an': 781,
#  'nations': 771,
#  'educational': 751,
#  'may': 735,
#  'united': 702,
#  'member': 697,
#  'from': 661,
#  'scientific': 656,
#  'national': 644,
#  'heritage': 631,
#  'organization': 629,
#  'general': 627,
#  'parties': 624,
#  'have': 583,
#  'public': 566,
#  'higher': 566,
#  'protection': 536,
#  'human': 507,
#  'rights': 504,
#  'institutions': 496,
#  'development': 493,
#  'property': 488,
#  'information': 483,
#  'recommendation': 481,
#  'provisions': 474,
#  'each': 464,
#  'measures': 463,
#  'conference': 454,
#  'they': 445,
#  'into': 442,
#  'recognition': 435,
#  'appropriate': 428,
#  'party': 406,
#  'take': 404,
#  'authorities': 393,
#  'social': 386,
#  'research': 382,
#  'under': 372,
#  'if': 371,
#  'including': 368,
#  'means': 367,
#  'within': 367,
#  'those': 353,
#  'between': 342,
#  'organizations': 341,
#  'present': 335,
#  'necessary': 330,
#  'also': 328,
#  'work': 327,
#  'principles': 324,
#  'studies': 324,
#  'made': 322,
#  'activities': 320,
#  'has': 317,
#  'ensure': 317,
#  'one': 312,
#  'them': 304,
#  'respect': 303,
#  'access': 303,
#  'well': 303,
#  'these': 302,
#  'particular': 301,
#  'conditions': 300,
#  'use': 300,
#  'unesco': 297,
#  'concerned': 295,
#  'works': 291,
#  'declaration': 291,
#  'provided': 284,
#  'where': 282,
#  'director-general': 281,
#  'accordance': 280,
#  'regional': 276,
#  'through': 274,
#  'concerning': 269,
#  'possible': 266,
#  'knowledge': 264,
#  'programmes': 264,
#  'committee': 263,
#  'out': 262,
#  'purpose': 259,
#  'paragraph': 258,
#  'competent': 252,
#  'qualifications': 251,
#  'following': 248,
#  'learning': 247,
#  'ii': 246,
#  'teachers': 245,
#  'world': 244,
#  'countries': 242,
#  'no': 242,
#  'so': 241,
#  'application': 239,
#  'teaching': 239,
#  'order': 238,
#  'promote': 238,
#  'right': 236,
#  'training': 231,
#  'ratification': 230,
#  'purposes': 229,
#  'economic': 228,
#  'after': 226,
#  'time': 226,
#  'natural': 226,
#  'territory': 218,
#  'accession': 217,
#  'bodies': 216,
#  'been': 214,
#  'force': 213,
#  'law': 212,
#  'encourage': 212,
#  'only': 211,
#  'part': 208,
#  'data': 207,
#  'when': 206,
#  'technical': 205,
#  'referred': 204,
#  'acceptance': 204,
#  'country': 203,
#  'taken': 202,
#  'set': 201,
#  'adopted': 200,
#  'more': 198,
#  'agreement': 198,
#  'considering': 198,
#  'subject': 197,
#  'session': 197,
#  'apply': 197,
#  'persons': 196,
#  'groups': 196,
#  'diversity': 195,
#  'who': 195,
#  'co-operation': 195,
#  'private': 192,
#  'members': 188,
#  'level': 188,
#  'make': 186,
#  'provide': 185,
#  'date': 182,
#  'without': 180,
#  'special': 179,
#  'physical': 179,
#  'personnel': 178,
#  'quality': 178,
#  'life': 178,
#  'can': 177,
#  'will': 176,
#  'professional': 176,
#  'diplomas': 174,
#  'among': 173,
#  'standards': 173,
#  'services': 173,
#  'museums': 173,
#  'view': 172,
#  'resources': 172,
#  'effect': 171,
#  'copyright': 171,
#  'system': 170,
#  'action': 168,
#  'up': 168,
#  'but': 168,
#  'iii': 167,
#  'exchange': 166,
#  'regulations': 166,
#  'instrument': 166,
#  'institution': 166,
#  'preservation': 166,
#  'policies': 165,
#  'degrees': 165,
#  'being': 164,
#  'forms': 163,
#  'form': 163,
#  'relevant': 162,
#  'effective': 160,
#  'both': 160,
#  'programme': 159,
#  'same': 158,
#  'account': 158,
#  'universal': 157,
#  'study': 156,
#  'publications': 155,
#  'areas': 155,
#  'culture': 153,
#  'responsible': 153,
#  'broadcasting': 153,
#  'support': 152,
#  'activity': 152,
#  'implementation': 152,
#  'number': 150,
#  'instruments': 149,
#  'his': 148,
#  'local': 148,
#  'new': 147,
#  'relating': 147,
#  'peoples': 146,
#  'artistic': 146,
#  'given': 146,
#  'deposited': 145,
#  'urban': 145,
#  'period': 144,
#  'taking': 142,
#  'material': 142,
#  'statistics': 141,
#  'first': 141,
#  'person': 140,
#  'copies': 140,
#  'historic': 140,
#  'than': 139,
#  'open': 137,
#  'having': 136,
#  'two': 136,
#  'months': 136,
#  'individuals': 135,
#  'underwater': 135,
#  'safeguarding': 134,
#  'peace': 133,
#  'articles': 133,
#  'academic': 133,
#  'individual': 133,
#  'november': 132,
#  'conservation': 132,
#  'society': 132,
#  'understanding': 131,
#  'agreements': 131,
#  'iv': 131,
#  'against': 131,
#  'sport': 131,
#  'systems': 130,
#  'legal': 130,
#  'regard': 129,
#  'include': 129,
#  'higher-education': 129,
#  'community': 129,
#  'give': 128,
#  'day': 128,
#  'levels': 128,
#  'available': 128,
#  'own': 127,
#  'artists': 127,
#  'case': 126,
#  'policy': 126,
#  'must': 125,
#  'upon': 125,
#  'importance': 125,
#  'recognized': 124,
#  'different': 124,
#  'facilitate': 124,
#  'established': 123,
#  'deposit': 123,
#  'value': 123,
#  'used': 123,
#  'cooperation': 122,
#  'legislation': 122,
#  'developing': 122,
#  'royalties': 122,
#  'discrimination': 121,
#  'every': 120,
#  'defined': 119,
#  'participation': 119,
#  'practice': 119,
#  'request': 118,
#  'people': 117,
#  'due': 117,
#  'further': 116,
#  'required': 116,
#  'need': 116,
#  'publication': 116,
#  'archaeological': 116,
#  'whether': 115,
#  'communication': 114,
#  'fundamental': 114,
#  'territories': 114,
#  'government': 114,
#  'another': 114,
#  'steps': 113,
#  'interest': 112,
#  'domestic': 111,
#  'specific': 111,
#  'status': 111,
#  'employment': 111,
#  'published': 110,
#  'service': 110,
#  'notification': 110,
#  'develop': 109,
#  'authority': 109,
#  'high': 109,
#  'methods': 108,
#  'based': 107,
#  'before': 107,
#  'considered': 107,
#  'free': 106,
#  'science': 106,
#  'nature': 106,
#  'basis': 106,
#  'establishment': 106,
#  'objectives': 105,
#  'whose': 104,
#  'conformity': 104,
#  'years': 103,
#  'adopt': 103,
#  'language': 102,
#  'role': 102,
#  'existing': 102,
#  'benefit': 102,
#  'freedom': 101,
#  'bilateral': 101,
#  'definitions': 101,
#  'sites': 101,
#  'promoting': 100,
#  'he': 100,
#  'however': 100,
#  'particularly': 100,
#  'certificates': 100,
#  'according': 100,
#  'undertake': 99,
#  'obtained': 99,
#  'requirements': 99,
#  'situated': 99,
#  'political': 98,
#  'far': 98,
#  'opportunities': 97,
#  'responsibility': 97,
#  'either': 97,
#  'recognizing': 97,
#  'applicable': 97,
#  'constitutional': 97,
#  'important': 97,
#  'conventions': 96,
#  'qualification': 96,
#  'genetic': 96,
#  'contribute': 95,
#  'materials': 95,
#  'character': 95,
#  'whole': 94,
#  'environment': 94,
#  'mutual': 93,
#  'full': 93,
#  'approval': 93,
#  'change': 93,
#  'admission': 93,
#  'attention': 93,
#  'three': 93,
#  'assistance': 92,
#  'manner': 92,
#  'administrative': 92,
#  'adequate': 92,
#  'communities': 92,
#  'place': 91,
#  'term': 91,
#  'promotion': 91,
#  'granted': 91,
#  'denunciation': 91,
#  'terms': 90,
#  'above': 90,
#  'related': 90,
#  'entry': 90,
#  'framework': 90,
#  'procedure': 89,
#  'school': 89,
#  'essential': 89,
#  'intergovernmental': 88,
#  'way': 88,
#  'carried': 88,
#  'production': 88,
#  'recommends': 88,
#  'financial': 87,
#  'dissemination': 87,
#  'recalling': 87,
#  'various': 87,
#  'media': 87,
#  'security': 86,
#  'cultures': 86,
#  'meeting': 85,
#  'adult': 85,
#  'future': 85,
#  'moving': 85,
#  'tvet': 85,
#  'dignity': 84,
#  'arrangements': 84,
#  'commission': 84,
#  'rules': 84,
#  'creation': 84,
#  'procedures': 84,
#  'images': 84,
#  'etc': 84,
#  'respective': 83,
#  'laws': 83,
#  'there': 83,
#  'foreign': 83,
#  'structures': 83,
#  'needs': 83,
#  'oer': 83,
#  'books': 82,
#  'enter': 82,
#  'management': 82,
#  'generations': 82,
#  'climate': 82,
#  'prejudice': 81,
#  'relations': 81,
#  'issued': 81,
#  'skills': 81,
#  'most': 81,
#  'provision': 81,
#  'problems': 81,
#  'health': 81,
#  'interests': 80,
#  'profession': 80,
#  'constitution': 79,
#  'art': 79,
#  'staff': 79,
#  'decisions': 78,
#  'least': 78,
#  'protect': 78,
#  'paris': 78,
#  'collections': 78,
#  'planning': 78,
#  'would': 77,
#  'end': 77,
#  'recommendations': 77,
#  'stakeholders': 77,
#  'anti-doping': 77,
#  'buildings': 77,
#  'invited': 76,
#  'freedoms': 75,
#  'practices': 75,
#  'assessment': 74,
#  'literary': 74,
#  'translation': 74,
#  'equality': 73,
#  'matters': 73,
#  'december': 73,
#  'ensuring': 73,
#  'students': 73,
#  'does': 73,
#  'during': 72,
#  'secretariat': 72,
#  'cases': 72,
#  'meet': 72,
#  'vi': 72,
#  'already': 72,
#  'sustainable': 72,
#  'region': 72,
#  'protected': 72,
#  'intellectual': 71,
#  'functions': 71,
#  'board': 71,
#  'year': 71,
#  'vocational': 71,
#  'certificate': 71,
#  'while': 71,
#  'consent': 71,
#  'folklore': 71,
#  'determined': 70,
#  'exchanges': 70,
#  'certain': 70,
#  'periodicals': 70,
#  'digital': 70,
#  'consider': 69,
#  'unless': 69,
#  'associations': 69,
#  'recognize': 69,
#  'process': 69,
#  'similar': 69,
#  'secretary-general': 69}
